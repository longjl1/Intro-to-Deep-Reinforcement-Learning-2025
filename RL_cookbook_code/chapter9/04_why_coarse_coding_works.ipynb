# %% [markdown]
# # Chapter 9: Why We Use Coarse Coding

# %% [markdown]
# Coarse coding supports generalization: updates at one point can influence nearby points because they share overlapping features.

# %% [markdown]
# That is the main tradeoff: we lose exact local detail, but we gain the ability to learn useful structure from relatively little data.
