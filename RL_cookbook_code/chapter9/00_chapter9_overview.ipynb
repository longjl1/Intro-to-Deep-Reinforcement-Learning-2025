# %% [markdown]
# # Sutton & Barto Chapter 9 Overview
# ## On-policy Prediction with Approximation

# %% [markdown]
# This folder focuses on linear function approximation, state aggregation, coarse coding, and tile coding intuition.

# %% [markdown]
# ## Suggested Reading Flow
#
# Start with state aggregation, then move to coarse coding for generalization intuition, and end with tile coding because it prepares the ground for Chapter 10 control methods.
