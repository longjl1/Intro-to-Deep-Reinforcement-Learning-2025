# %% [markdown]
# # Chapter 4: Jack's Car Rental Setup

# %% [markdown]
# Jack's Car Rental is a larger dynamic programming example that combines Poisson rental requests, overnight transfers, and value-based planning.
#
# This notebook records the modeling ingredients rather than a full heavy implementation.

# %%
max_cars = 20
max_move = 5
rental_reward = 10
move_cost = 2

state_example = (10, 12)
possible_moves = list(range(-min(max_move, state_example[1]), min(max_move, state_example[0]) + 1))
possible_moves[:5], possible_moves[-5:]

# %% [markdown]
# This example becomes computationally expensive because each action changes the next-day state distribution, and those distributions involve rental and return randomness at both locations.
