# %% [markdown]
# # Chapter 10: Access-Control Queuing Task Setup

# %%
free_servers = 10
job_priorities = [1, 2, 4, 8]

state = {'free_servers': 6, 'priority': 4}
actions = ['reject', 'accept']
state, actions
