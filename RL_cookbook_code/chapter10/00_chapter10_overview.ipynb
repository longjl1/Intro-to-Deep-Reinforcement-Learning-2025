# %% [markdown]
# # Sutton & Barto Chapter 10 Overview
# ## On-policy Control with Approximation

# %% [markdown]
# This folder focuses on approximate control methods such as semi-gradient Sarsa, n-step Sarsa, and average-reward learning.

# %% [markdown]
# ## Suggested Reading Flow
#
# Begin with the Mountain Car feature setup, then the approximate Sarsa methods, and finish with the access-control queue because it shifts the discussion toward continuing tasks and average reward.
