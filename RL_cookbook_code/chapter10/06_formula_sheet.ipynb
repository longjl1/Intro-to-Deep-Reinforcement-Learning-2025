# %% [markdown]
# # Chapter 10 Formula Sheet
#
# ## Semi-gradient Sarsa
# $$
# \mathbf{w}_{t+1} = \mathbf{w}_t + \alpha [R_{t+1} + \gamma \hat{q}(S_{t+1},A_{t+1},\mathbf{w}_t) - \hat{q}(S_t,A_t,\mathbf{w}_t)] \nabla \hat{q}(S_t,A_t,\mathbf{w}_t)
# $$
#
# ## R-learning average-reward idea
# Learn differential action values together with an average reward estimate $\rho$.
