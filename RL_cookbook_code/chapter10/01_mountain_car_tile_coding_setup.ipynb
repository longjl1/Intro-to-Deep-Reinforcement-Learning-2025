# %% [markdown]
# # Chapter 10: Mountain Car Tile Coding Setup

# %%
import numpy as np

position_range = (-1.2, 0.5)
velocity_range = (-0.07, 0.07)
actions = [0, 1, 2]

def normalize(x, low, high):
    return (x - low) / (high - low)

sample = (normalize(-0.5, *position_range), normalize(0.02, *velocity_range))
sample
