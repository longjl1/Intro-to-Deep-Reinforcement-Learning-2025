# %% [markdown]
# # Chapter 5: Blackjack Environment Setup

# %% [markdown]
# The blackjack examples in Sutton and Barto use states such as player sum, dealer showing card, and whether the player has a usable ace.

# %%
sample_state = {'player_sum': 18, 'dealer_showing': 6, 'usable_ace': True}
actions = ['stick', 'hit']
sample_state, actions
