# %% [markdown]
# # Chapter 5: Monte Carlo Control with Exploring Starts

# %% [markdown]
# Exploring starts assumes every state-action pair can be sampled with nonzero probability at the beginning of an episode. This makes it possible to improve a policy from complete episodic returns.

# %%
mc_es_loop = [
    'sample an episode from a start state-action pair',
    'estimate returns for visited state-action pairs',
    'make the policy greedy with respect to current action values',
]
mc_es_loop
