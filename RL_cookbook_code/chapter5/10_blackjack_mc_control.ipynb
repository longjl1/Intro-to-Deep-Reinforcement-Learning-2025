# %% [markdown]
# # Chapter 5: Blackjack Monte Carlo Control

# %% [markdown]
# Blackjack is a classic environment for Monte Carlo control because episodes end naturally and sampled returns can be averaged directly.

# %% [markdown]
# A learned policy is often easy to summarize as regions of the state space where the player should stick versus regions where the player should hit.

# %% [markdown]
# In the full textbook example, this is usually shown as a pair of policy surfaces split by whether the player has a usable ace.
