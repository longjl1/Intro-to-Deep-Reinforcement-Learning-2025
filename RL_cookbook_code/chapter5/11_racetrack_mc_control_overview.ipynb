# %% [markdown]
# # Chapter 5: Racetrack Monte Carlo Control Overview

# %% [markdown]
# The racetrack problem illustrates Monte Carlo control in a larger episodic setting with delayed consequences and stochastic transitions.

# %% [markdown]
# Typical state variables include position and velocity, while actions adjust acceleration. Because rewards arrive over long trajectories, Monte Carlo returns provide a natural training signal.
