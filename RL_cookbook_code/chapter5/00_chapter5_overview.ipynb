# %% [markdown]
# # Sutton & Barto Chapter 5 Overview
# ## Monte Carlo Methods
#
# This notebook is a roadmap for the Monte Carlo materials in this folder.

# %% [markdown]
# ## Core Themes
#
# - Monte Carlo prediction
# - first-visit and every-visit estimation
# - Monte Carlo control
# - exploring starts
# - epsilon-soft policies
# - off-policy learning with importance sampling
# - blackjack and racetrack examples

# %% [markdown]
# ## Suggested Reading Flow
#
# Start with prediction, then compare first-visit and every-visit estimation, then move to control, and finally to off-policy learning with importance sampling.
