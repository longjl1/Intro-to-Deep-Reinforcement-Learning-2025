# %% [markdown]
# # Chapter 5: Blackjack Monte Carlo Prediction

# %%
returns = {(20, 10, False): [1, 1, 0, 1], (13, 2, True): [-1, 0, 1]}
values = {s: sum(gs) / len(gs) for s, gs in returns.items()}
values

# %% [markdown]
# These averages are tiny stand-ins for the larger Monte Carlo state-value tables commonly visualized in the blackjack example.
