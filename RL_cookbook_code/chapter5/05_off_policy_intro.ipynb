# %% [markdown]
# # Chapter 5: Off-Policy Monte Carlo Introduction

# %% [markdown]
# Off-policy learning separates the behavior policy that generates data from the target policy we want to evaluate or improve.
