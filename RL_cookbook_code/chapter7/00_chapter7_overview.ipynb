# %% [markdown]
# # Sutton & Barto Chapter 7 Overview
# ## n-step Bootstrapping

# %% [markdown]
# This chapter bridges one-step TD and Monte Carlo methods by using n-step returns.

# %% [markdown]
# ## Suggested Reading Flow
#
# Compare online and offline n-step TD first, then use the comparison notebook to think about how the choice of n changes learning behavior.
