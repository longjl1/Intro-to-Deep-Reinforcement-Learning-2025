# %% [markdown]
# # Sutton & Barto Chapter 8 Overview
# ## Planning and Learning with Tabular Methods

# %% [markdown]
# This folder focuses on model-based updates, planning backups, and trajectory sampling.

# %% [markdown]
# A useful theme in this chapter is that learning and planning use the same backup ideas; the difference is whether the update is driven by real experience or a model.
