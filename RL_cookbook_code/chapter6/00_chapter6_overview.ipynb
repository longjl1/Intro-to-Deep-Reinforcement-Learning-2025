# %% [markdown]
# # Sutton & Barto Chapter 6 Overview
# ## Temporal-Difference Learning
#
# This folder collects compact Python notebooks for Chapter 6 topics, centered on temporal-difference prediction and control.

# %% [markdown]
# ## Topics
#
# - TD prediction on the random walk
# - batch training comparison between TD and Monte Carlo
# - an alternate random-walk implementation
# - conventional Q-learning vs Double Q-learning
# - small formula summaries and implementation notes

# %% [markdown]
# ## Suggested Reading Flow
#
# Start with TD prediction on the random walk, then compare batch TD and Monte Carlo, and finally move to the control-side overestimation example with Double Q-learning.
