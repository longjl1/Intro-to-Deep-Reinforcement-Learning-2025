# %% [markdown]
# ## Hw1
#
# Using a modified 10-armed Bandit in this exercise to demonstrate the limitations of sample-average methods when dealing with nonstationary problems. We will compare two different action-value estimation methods:
# Sample-average method (SA)
# Constant step-size method (CS)

# %% [markdown]
# 10-armed bandit:

# %%
import numpy as np
import matplotlib.pyplot as plt
import random, math

np.random.seed(1)

class ten_armed_bandit:
    def __init__(self, k=10, walks=0.01):
        self.arms = k
        self.walks = 0.01
        self.q_t = np.zeros(k)

    def reward(self, arm):
        return np.random.normal(self.q_t[arm], 1)

    def update_q_t(self):
        self.q_t += np.random.normal(0, self.walks, self.arms)

    def find_best_arm(self):
        return np.argmax(self.q_t)

# %%
def run(k_arms=10,walks = 0.01, num_steps=10000, num_exp = 2000, ep=0.1, a_val = 0.1, sample_average=True):
    avg_rewards = np.zeros(num_steps)
    opt_arms = np.zeros(num_steps)

    for exp in range(num_exp):
        if exp % 10 == 0:
            print(f"Experiment {exp}/{num_exp} ...")

        bandit = ten_armed_bandit(k=k_arms, walks=walks)

        est_Q = np.zeros(bandit.arms) #Q values for each arm
        arm_counts = np.zeros(bandit.arms)

        for step in range(num_steps):
            if np.random.rand() < ep:
                arm = np.random.randint(bandit.arms)
            else:
                arm = np.argmax(est_Q)

            #reward
            reward = bandit.reward(arm) 
            
            bandit.update_q_t()
            opt_arm = bandit.find_best_arm()

            #update
            if sample_average == True:
                arm_counts[arm] += 1
                est_Q[arm] += (reward - est_Q[arm]) / arm_counts[arm]
            else:
                est_Q[arm] += a_val*(reward - est_Q[arm])
            
            #results
            avg_rewards[step] += reward
            if arm == opt_arm:
                opt_arms[step] += 1

    avg_rewards /= num_exp
    opt_arms = (opt_arms / num_exp) * 100

    return avg_rewards, opt_arms

# %% [markdown]
# #### Experiment:

# %%
num_arms = 10  
num_steps = 20000  
num_exp = 2000  
epsilon = 0.1  
alpha = 0.1 
random_walks = 0.01 

avg_rewards_SA, opt_arms_SA = run(num_arms, random_walks, num_steps, num_exp, epsilon, alpha, sample_average=True)
avg_rewards_CS, opt_arms_CS = run(num_arms, random_walks, num_steps, num_exp, epsilon, alpha, sample_average=False)

plt.figure(figsize=(10, 5))
plt.plot(avg_rewards_SA, label="Sample-Average")
plt.plot(avg_rewards_CS, label="Constant Step-Size (alpha=0.1)")
plt.xlabel("Steps")
plt.ylabel("Average Reward")
plt.title("Average Reward Comparison")
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(opt_arms_SA, label="Sample-Average")
plt.plot(opt_arms_CS, label="Constant Step-Size (alpha=0.1)")
plt.xlabel("Steps")
plt.ylabel("% Optimal Action")
plt.title("Optimal Action Selection Comparison")
plt.legend()
plt.show()
# Out:
# Experiment 0/2000 ...
# Experiment 10/2000 ...
# Experiment 20/2000 ...
# Experiment 30/2000 ...
# Experiment 40/2000 ...
# Experiment 50/2000 ...
# Experiment 60/2000 ...
# Experiment 70/2000 ...
# Experiment 80/2000 ...
# Experiment 90/2000 ...
# Experiment 100/2000 ...
# Experiment 110/2000 ...
# Experiment 120/2000 ...
# Experiment 130/2000 ...
# Experiment 140/2000 ...
# Experiment 150/2000 ...
# Experiment 160/2000 ...
# Experiment 170/2000 ...
# Experiment 180/2000 ...
# Experiment 190/2000 ...
# Experiment 200/2000 ...
# Experiment 210/2000 ...
# Experiment 220/2000 ...
# Experiment 230/2000 ...
# Experiment 240/2000 ...
# Experiment 250/2000 ...
# Experiment 260/2000 ...
# Experiment 270/2000 ...
# Experiment 280/2000 ...
# Experiment 290/2000 ...
# Experiment 300/2000 ...
# Experiment 310/2000 ...
# Experiment 320/2000 ...
# Experiment 330/2000 ...
# Experiment 340/2000 ...
# Experiment 350/2000 ...
# Experiment 360/2000 ...
# Experiment 370/2000 ...
# Experiment 380/2000 ...
# Experiment 390/2000 ...
# Experiment 400/2000 ...
# Experiment 410/2000 ...
# Experiment 420/2000 ...
# Experiment 430/2000 ...
# Experiment 440/2000 ...
# Experiment 450/2000 ...
# Experiment 460/2000 ...
# Experiment 470/2000 ...
# Experiment 480/2000 ...
# Experiment 490/2000 ...
# Experiment 500/2000 ...
# Experiment 510/2000 ...
# Experiment 520/2000 ...
# Experiment 530/2000 ...
# Experiment 540/2000 ...
# Experiment 550/2000 ...
# Experiment 560/2000 ...
# Experiment 570/2000 ...
# Experiment 580/2000 ...
# Experiment 590/2000 ...
# Experiment 600/2000 ...
# Experiment 610/2000 ...
# Experiment 620/2000 ...
# Experiment 630/2000 ...
# Experiment 640/2000 ...
# Experiment 650/2000 ...
# Experiment 660/2000 ...
# Experiment 670/2000 ...
# Experiment 680/2000 ...
# Experiment 690/2000 ...
# Experiment 700/2000 ...
# Experiment 710/2000 ...
# Experiment 720/2000 ...
# Experiment 730/2000 ...
# Experiment 740/2000 ...
# Experiment 750/2000 ...
# Experiment 760/2000 ...
# Experiment 770/2000 ...
# Experiment 780/2000 ...
# Experiment 790/2000 ...
# Experiment 800/2000 ...
# Experiment 810/2000 ...
# Experiment 820/2000 ...
# Experiment 830/2000 ...
# Experiment 840/2000 ...
# Experiment 850/2000 ...
# Experiment 860/2000 ...
# Experiment 870/2000 ...
# Experiment 880/2000 ...
# Experiment 890/2000 ...
# Experiment 900/2000 ...
# Experiment 910/2000 ...
# Experiment 920/2000 ...
# Experiment 930/2000 ...
# Experiment 940/2000 ...
# Experiment 950/2000 ...
# Experiment 960/2000 ...
# Experiment 970/2000 ...
# Experiment 980/2000 ...
# Experiment 990/2000 ...
# Experiment 1000/2000 ...
# Experiment 1010/2000 ...
# Experiment 1020/2000 ...
# Experiment 1030/2000 ...
# Experiment 1040/2000 ...
# Experiment 1050/2000 ...
# Experiment 1060/2000 ...
# Experiment 1070/2000 ...
# Experiment 1080/2000 ...
# Experiment 1090/2000 ...
# Experiment 1100/2000 ...
# Experiment 1110/2000 ...
# Experiment 1120/2000 ...
# Experiment 1130/2000 ...
# Experiment 1140/2000 ...
# Experiment 1150/2000 ...
# Experiment 1160/2000 ...
# Experiment 1170/2000 ...
# Experiment 1180/2000 ...
# Experiment 1190/2000 ...
# Experiment 1200/2000 ...
# Experiment 1210/2000 ...
# Experiment 1220/2000 ...
# Experiment 1230/2000 ...
# Experiment 1240/2000 ...
# Experiment 1250/2000 ...
# Experiment 1260/2000 ...
# Experiment 1270/2000 ...
# Experiment 1280/2000 ...
# Experiment 1290/2000 ...
# Experiment 1300/2000 ...
# Experiment 1310/2000 ...
# Experiment 1320/2000 ...
# Experiment 1330/2000 ...
# Experiment 1340/2000 ...
# Experiment 1350/2000 ...
# Experiment 1360/2000 ...
# Experiment 1370/2000 ...
# Experiment 1380/2000 ...
# Experiment 1390/2000 ...
# Experiment 1400/2000 ...
# Experiment 1410/2000 ...
# Experiment 1420/2000 ...
# Experiment 1430/2000 ...
# Experiment 1440/2000 ...
# Experiment 1450/2000 ...
# Experiment 1460/2000 ...
# Experiment 1470/2000 ...
# Experiment 1480/2000 ...
# Experiment 1490/2000 ...
# Experiment 1500/2000 ...
# Experiment 1510/2000 ...
# Experiment 1520/2000 ...
# Experiment 1530/2000 ...
# Experiment 1540/2000 ...
# Experiment 1550/2000 ...
# Experiment 1560/2000 ...
# Experiment 1570/2000 ...
# Experiment 1580/2000 ...
# Experiment 1590/2000 ...
# Experiment 1600/2000 ...
# Experiment 1610/2000 ...
# Experiment 1620/2000 ...
# Experiment 1630/2000 ...
# Experiment 1640/2000 ...
# Experiment 1650/2000 ...
# Experiment 1660/2000 ...
# Experiment 1670/2000 ...
# Experiment 1680/2000 ...
# Experiment 1690/2000 ...
# Experiment 1700/2000 ...
# Experiment 1710/2000 ...
# Experiment 1720/2000 ...
# Experiment 1730/2000 ...
# Experiment 1740/2000 ...
# Experiment 1750/2000 ...
# Experiment 1760/2000 ...
# Experiment 1770/2000 ...
# Experiment 1780/2000 ...
# Experiment 1790/2000 ...
# Experiment 1800/2000 ...
# Experiment 1810/2000 ...
# Experiment 1820/2000 ...
# Experiment 1830/2000 ...
# Experiment 1840/2000 ...
# Experiment 1850/2000 ...
# Experiment 1860/2000 ...
# Experiment 1870/2000 ...
# Experiment 1880/2000 ...
# Experiment 1890/2000 ...
# Experiment 1900/2000 ...
# Experiment 1910/2000 ...
# Experiment 1920/2000 ...
# Experiment 1930/2000 ...
# Experiment 1940/2000 ...
# Experiment 1950/2000 ...
# Experiment 1960/2000 ...
# Experiment 1970/2000 ...
# Experiment 1980/2000 ...
# Experiment 1990/2000 ...
# Experiment 0/2000 ...
# Experiment 10/2000 ...
# Experiment 20/2000 ...
# Experiment 30/2000 ...
# Experiment 40/2000 ...
# Experiment 50/2000 ...
# Experiment 60/2000 ...
# Experiment 70/2000 ...
# Experiment 80/2000 ...
# Experiment 90/2000 ...
# Experiment 100/2000 ...
# Experiment 110/2000 ...
# Experiment 120/2000 ...
# Experiment 130/2000 ...
# Experiment 140/2000 ...
# Experiment 150/2000 ...
# Experiment 160/2000 ...
# Experiment 170/2000 ...
# Experiment 180/2000 ...
# Experiment 190/2000 ...
# Experiment 200/2000 ...
# Experiment 210/2000 ...
# Experiment 220/2000 ...
# Experiment 230/2000 ...
# Experiment 240/2000 ...
# Experiment 250/2000 ...
# Experiment 260/2000 ...
# Experiment 270/2000 ...
# Experiment 280/2000 ...
# Experiment 290/2000 ...
# Experiment 300/2000 ...
# Experiment 310/2000 ...
# Experiment 320/2000 ...
# Experiment 330/2000 ...
# Experiment 340/2000 ...
# Experiment 350/2000 ...
# Experiment 360/2000 ...
# Experiment 370/2000 ...
# Experiment 380/2000 ...
# Experiment 390/2000 ...
# Experiment 400/2000 ...
# Experiment 410/2000 ...
# Experiment 420/2000 ...
# Experiment 430/2000 ...
# Experiment 440/2000 ...
# Experiment 450/2000 ...
# Experiment 460/2000 ...
# Experiment 470/2000 ...
# Experiment 480/2000 ...
# Experiment 490/2000 ...
# Experiment 500/2000 ...
# Experiment 510/2000 ...
# Experiment 520/2000 ...
# Experiment 530/2000 ...
# Experiment 540/2000 ...
# Experiment 550/2000 ...
# Experiment 560/2000 ...
# Experiment 570/2000 ...
# Experiment 580/2000 ...
# Experiment 590/2000 ...
# Experiment 600/2000 ...
# Experiment 610/2000 ...
# Experiment 620/2000 ...
# Experiment 630/2000 ...
# Experiment 640/2000 ...
# Experiment 650/2000 ...
# Experiment 660/2000 ...
# Experiment 670/2000 ...
# Experiment 680/2000 ...
# Experiment 690/2000 ...
# Experiment 700/2000 ...
# Experiment 710/2000 ...
# Experiment 720/2000 ...
# Experiment 730/2000 ...
# Experiment 740/2000 ...
# Experiment 750/2000 ...
# Experiment 760/2000 ...
# Experiment 770/2000 ...
# Experiment 780/2000 ...
# Experiment 790/2000 ...
# Experiment 800/2000 ...
# Experiment 810/2000 ...
# Experiment 820/2000 ...
# Experiment 830/2000 ...
# Experiment 840/2000 ...
# Experiment 850/2000 ...
# Experiment 860/2000 ...
# Experiment 870/2000 ...
# Experiment 880/2000 ...
# Experiment 890/2000 ...
# Experiment 900/2000 ...
# Experiment 910/2000 ...
# Experiment 920/2000 ...
# Experiment 930/2000 ...
# Experiment 940/2000 ...
# Experiment 950/2000 ...
# Experiment 960/2000 ...
# Experiment 970/2000 ...
# Experiment 980/2000 ...
# Experiment 990/2000 ...
# Experiment 1000/2000 ...
# Experiment 1010/2000 ...
# Experiment 1020/2000 ...
# Experiment 1030/2000 ...
# Experiment 1040/2000 ...
# Experiment 1050/2000 ...
# Experiment 1060/2000 ...
# Experiment 1070/2000 ...
# Experiment 1080/2000 ...
# Experiment 1090/2000 ...
# Experiment 1100/2000 ...
# Experiment 1110/2000 ...
# Experiment 1120/2000 ...
# Experiment 1130/2000 ...
# Experiment 1140/2000 ...
# Experiment 1150/2000 ...
# Experiment 1160/2000 ...
# Experiment 1170/2000 ...
# Experiment 1180/2000 ...
# Experiment 1190/2000 ...
# Experiment 1200/2000 ...
# Experiment 1210/2000 ...
# Experiment 1220/2000 ...
# Experiment 1230/2000 ...
# Experiment 1240/2000 ...
# Experiment 1250/2000 ...
# Experiment 1260/2000 ...
# Experiment 1270/2000 ...
# Experiment 1280/2000 ...
# Experiment 1290/2000 ...
# Experiment 1300/2000 ...
# Experiment 1310/2000 ...
# Experiment 1320/2000 ...
# Experiment 1330/2000 ...
# Experiment 1340/2000 ...
# Experiment 1350/2000 ...
# Experiment 1360/2000 ...
# Experiment 1370/2000 ...
# Experiment 1380/2000 ...
# Experiment 1390/2000 ...
# Experiment 1400/2000 ...
# Experiment 1410/2000 ...
# Experiment 1420/2000 ...
# Experiment 1430/2000 ...
# Experiment 1440/2000 ...
# Experiment 1450/2000 ...
# Experiment 1460/2000 ...
# Experiment 1470/2000 ...
# Experiment 1480/2000 ...
# Experiment 1490/2000 ...
# Experiment 1500/2000 ...
# Experiment 1510/2000 ...
# Experiment 1520/2000 ...
# Experiment 1530/2000 ...
# Experiment 1540/2000 ...
# Experiment 1550/2000 ...
# Experiment 1560/2000 ...
# Experiment 1570/2000 ...
# Experiment 1580/2000 ...
# Experiment 1590/2000 ...
# Experiment 1600/2000 ...
# Experiment 1610/2000 ...
# Experiment 1620/2000 ...
# Experiment 1630/2000 ...
# Experiment 1640/2000 ...
# Experiment 1650/2000 ...
# Experiment 1660/2000 ...
# Experiment 1670/2000 ...
# Experiment 1680/2000 ...
# Experiment 1690/2000 ...
# Experiment 1700/2000 ...
# Experiment 1710/2000 ...
# Experiment 1720/2000 ...
# Experiment 1730/2000 ...
# Experiment 1740/2000 ...
# Experiment 1750/2000 ...
# Experiment 1760/2000 ...
# Experiment 1770/2000 ...
# Experiment 1780/2000 ...
# Experiment 1790/2000 ...
# Experiment 1800/2000 ...
# Experiment 1810/2000 ...
# Experiment 1820/2000 ...
# Experiment 1830/2000 ...
# Experiment 1840/2000 ...
# Experiment 1850/2000 ...
# Experiment 1860/2000 ...
# Experiment 1870/2000 ...
# Experiment 1880/2000 ...
# Experiment 1890/2000 ...
# Experiment 1900/2000 ...
# Experiment 1910/2000 ...
# Experiment 1920/2000 ...
# Experiment 1930/2000 ...
# Experiment 1940/2000 ...
# Experiment 1950/2000 ...
# Experiment 1960/2000 ...
# Experiment 1970/2000 ...
# Experiment 1980/2000 ...
# Experiment 1990/2000 ...
